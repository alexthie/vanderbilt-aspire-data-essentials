# %%
import pandas as pd

# %%
### import data

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# '/Users/thiemia/vanderbilt-aspire-data-essentials/data'

# %%
os.chdir('/Users/thiemia/vanderbilt-aspire-data-essentials')

# %%
hospice_df = pd.read_csv('data/Hospice_General_Information.csv')

# %%
hospice_df.tail(5)
# Out:
#       CMS Certification Number (CCN)                 Facility Name  \
# 4638                          921720  COMFORTING CARE HOSPICE, INC
# 4639                          921721     BLESSED HOPE HOSPICE, INC
# 4640                          921722        VISTA HOSPICE CARE INC
# 4641                          921723          NORCAL HOSPICE, INC.
# 4642                          921729   AFFECTIVE HOSPICE CARE, INC
#
#                          Address Line 1  Address Line 2            City State  \
# 4638  5924 E LOS ANGELES AVENUE SUITE L             NaN     SIMI VALLEY    CA
# 4639       2619 S WATERMAN AVE, SUITE D             NaN  SAN BERNARDINO    CA
# 4640      550 WEST VISTA WAY, SUITE 310             NaN           VISTA    CA
# 4641       700 W. 6TH STREET, SUITE K-B             NaN          GILROY    CA
# 4642  5050 PALO VERDE STREET, SUITE 208             NaN       MONTCLAIR    CA
#
#       Zip Code     County Name     PhoneNumber  CMS Region Ownership Type  \
# ...

# %%
hospice_df = hospice_df.loc[hospice_df.State =='TN']
hospice_df.head(5)
# Out:
#       CMS Certification Number (CCN)                       Facility Name  \
# 2889                          441501                   ALIVE HOSPICE INC
# 2890                          441502          METHODIST ALLIANCE HOSPICE
# 2891                          441504          HOSPICE OF CHATTANOOGA INC
# 2892                          441506               AMEDISYS HOSPICE CARE
# 2893                          441507  NORTHCREST HOME HEALTH AND HOSPICE
#
#                          Address Line 1  Address Line 2         City State  \
# 2889                1718 PATTERSON ROAD             NaN    NASHVILLE    TN
# 2890  6400 SHELBY VIEW DRIVE, SUITE 101             NaN      MEMPHIS    TN
# 2891                 4411 OAKWOOD DRIVE             NaN  CHATTANOOGA    TN
# 2892          6570 STAGE ROAD SUITE 110             NaN     BARTLETT    TN
# 2893               212 NORTHCREST DRIVE             NaN  SPRINGFIELD    TN
#
#       Zip Code County Name     PhoneNumber  CMS Region Ownership Type  \
# ...

# %%
# Keep only the **Facility Name**, **Address Line 1**, **City**, **State**, **County Name**, **CMS Region**, **Ownership Type**, and **Cerfification Date** columns. Make all column names lower case and without spaces.  
hospice_df.columns = ['ccn','facility','address','address2','city',
                      'state','zip','county','phone','region','owner_type','cert_date']
hospice_df.head(2)
# Out:
#          ccn                    facility                            address  \
# 2889  441501           ALIVE HOSPICE INC                1718 PATTERSON ROAD
# 2890  441502  METHODIST ALLIANCE HOSPICE  6400 SHELBY VIEW DRIVE, SUITE 101
#
#       address2       city state    zip    county           phone  region  \
# 2889       NaN  NASHVILLE    TN  37203  Davidson  (615) 327-1085       4
# 2890       NaN    MEMPHIS    TN  38134    Shelby  (901) 516-1600       4
#
#       owner_type   cert_date
# 2889  Non-Profit  04/10/1984
# 2890  Non-Profit  08/31/1984

# %%
hospice_df.count()
# Out:
# ccn           56
# facility      56
# address       56
# address2       0
# city          56
# state         56
# zip           56
# county        56
# phone         56
# region        56
# owner_type    56
# cert_date     56
# dtype: int64

# %%
#Examine the first 5 rows and the last five rows of the TN hospice data.

# %%
hospice_df.drop(columns=['ccn', 'address2','zip','phone'])
# Out:
#                                                facility  \
# 2889                                  ALIVE HOSPICE INC
# 2890                         METHODIST ALLIANCE HOSPICE
# 2891                         HOSPICE OF CHATTANOOGA INC
# 2892                              AMEDISYS HOSPICE CARE
# 2893                 NORTHCREST HOME HEALTH AND HOSPICE
# 2894                   HOSPICE OF CUMBERLAND COUNTY INC
# 2895                                  HIGHPOINT HOSPICE
# 2896                          HOSPICE OF WEST TENNESSEE
# 2897                                    KINDRED HOSPICE
# 2898                        TENNOVA HOSPICE-CLARKSVILLE
# 2899                AMEDISYS HOSPICE AN ADVENTA COMPANY
# 2900                   BLOUNT MEMORIAL HOSPITAL HOSPICE
# 2901                      ASERACARE HOSPICE - NASHVILLE
# 2902                                   SUNCREST HOSPICE
# 2903            LINCOLN MEDICAL HOME HEALTH AND HOSPICE
# 2904               AMEDISYS HOSPICE, AN ADVENTA COMPANY
# ...

# %%
hospice_df.shape
# Out:
# (56, 12)

# %%
df[:-3]

# %%
cancer_df = pd.read_csv('cancer_deaths.csv', skiprows=4, nrows=97)

# %%
cancer_df.head()
# Out:
#              County   FIPS Met Healthy People Objective of 161.4?  \
# 0         Tennessee  47999                                     No
# 1     United States      0                                     No
# 2  Trousdale County  47169                                     No
# 3      Scott County  47151                                     No
# 4   Cheatham County  47021                                     No
#
#    Age-Adjusted Death Rate - deaths per 100,000  \
# 0                                         185.4
# 1                                         163.5
# 2                                         265.5
# 3                                         241.0
# 4                                         239.6
#
#    Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                          184.0                          186.8
# 1                          163.3                          163.7
# 2                          219.0                          319.1
# ...

# %%
#Print the shape of the cancer data.

# %%
cancer_df.shape
# Out:
# (97, 11)

# %%
cancer_df.columns = ['county','fips','objmet','deathrate','lowconfi',
                      'upconfi','avgcount','rectrend','rectrend5ydeathrate','lowconfi1','upconfi1']
cancer_df.head(2)
# Out:
#           county   fips objmet  deathrate  lowconfi  upconfi  avgcount  \
# 0      Tennessee  47999     No      185.4     184.0    186.8     13933
# 1  United States      0     No      163.5     163.3    163.7    586354
#
#   rectrend  rectrend5ydeathrate  lowconfi1  upconfi1
# 0  falling                 -1.4       -1.5      -1.2
# 1  falling                 -1.5       -1.6      -1.5

# %%
pop_df = pd.read_csv('PEP_2017_PEPAGESEX.csv')
pop_df = pd.read_csv('PEP_2017_PEPAGESEX.csv')
pop_df.head(2)
# Out:
#            GEO.id GEO.id2           GEO.display-label  \
# 0              Id     Id2                   Geography
# 1  0500000US47001   47001  Anderson County, Tennessee
#
#                           cen42010sex0_age999  \
# 0  April 1, 2010 - Census - Both Sexes; Total
# 1                                       75129
#
#                     cen42010sex1_age999  \
# 0  April 1, 2010 - Census - Male; Total
# 1                                 36308
#
#                       cen42010sex2_age999  \
# 0  April 1, 2010 - Census - Female; Total
# 1                                   38821
#
#                                  est42010sex0_age999  \
# 0  April 1, 2010 - Estimates Base - Both Sexes; T...
# 1                                              75094
#
#                             est42010sex1_age999  \
# 0  April 1, 2010 - Estimates Base - Male; Total
# 1                                         36288
#
#                               est42010sex2_age999  \
# ...

# %%
pop_df.shape
# Out:
# (96, 894)

# %%
pop_df.tail(10)
# Out:
#             GEO.id GEO.id2             GEO.display-label cen42010sex0_age999  \
# 86  0500000US47171   47171      Unicoi County, Tennessee               18313
# 87  0500000US47173   47173       Union County, Tennessee               19109
# 88  0500000US47175   47175   Van Buren County, Tennessee                5548
# 89  0500000US47177   47177      Warren County, Tennessee               39839
# 90  0500000US47179   47179  Washington County, Tennessee              122979
# 91  0500000US47181   47181       Wayne County, Tennessee               17021
# 92  0500000US47183   47183     Weakley County, Tennessee               35021
# 93  0500000US47185   47185       White County, Tennessee               25841
# 94  0500000US47187   47187  Williamson County, Tennessee              183182
# 95  0500000US47189   47189      Wilson County, Tennessee              113993
#
#    cen42010sex1_age999 cen42010sex2_age999 est42010sex0_age999  \
# ...

# %%
list(pop_df)
# Out:
# ['GEO.id',
#  'GEO.id2',
#  'GEO.display-label',
#  'cen42010sex0_age999',
#  'cen42010sex1_age999',
#  'cen42010sex2_age999',
#  'est72010sex0_age999',
#  'est72010sex1_age999',
#  'est72010sex2_age999',
#  'est72011sex0_age999',
#  'est72011sex1_age999',
#  'est72011sex2_age999',
#  'est72012sex0_age999',
#  'est72012sex1_age999',
#  'est72012sex2_age999',
#  'est72013sex0_age999',
#  'est72013sex1_age999',
#  'est72013sex2_age999',
#  'est72014sex0_age999',
#  'est72014sex1_age999',
#  'est72014sex2_age999',
#  'est72015sex0_age999',
#  'est72015sex1_age999',
#  'est72015sex2_age999',
#  'est72016sex0_age999',
#  'est72016sex1_age999',
#  'est72016sex2_age999',
#  'est72017sex0_age999',
#  'est72017sex1_age999',
#  'est72017sex2_age999',
#  'cen42010sex0_age0to4',
#  'cen42010sex1_age0to4',
#  'cen42010sex2_age0to4',
#  'est72010sex0_age0to4',
#  'est72010sex1_age0to4',
#  'est72010sex2_age0to4',
#  'est72011sex0_age0to4',
#  'est72011sex1_age0to4',
#  'est72011sex2_age0to4',
# ...

# %%
pop_df1 = pop_df[pop_df.columns.drop(list(pop_df.filter(regex='est4')))]
pop_df2.shape
# Out:
# (96, 795)

# %%
#keep only columns that pertain to 2010, 2014, and 2017

# %%
pop_df2 = pop_df1[pop_df1.columns.drop(list(pop_df1.filter(regex='2011')))]
pop_df3 = pop_df2[pop_df2.columns.drop(list(pop_df2.filter(regex='2012')))]
pop_df4 = pop_df3[pop_df3.columns.drop(list(pop_df3.filter(regex='2013')))]
pop_df5 = pop_df4[pop_df4.columns.drop(list(pop_df4.filter(regex='2015')))]
pop_df6 = pop_df5[pop_df5.columns.drop(list(pop_df5.filter(regex='2016')))]
pop_df6.shape
# Out:
# (96, 399)

# %%
pop_df7 = pop_df6[pop_df6.columns.drop(list(pop_df6.filter(regex='age0')))]
pop_df8 = pop_df7[pop_df7.columns.drop(list(pop_df7.filter(regex='age5')))]
pop_df9 = pop_df8[pop_df8.columns.drop(list(pop_df8.filter(regex='age10')))]
pop_df10 = pop_df9[pop_df9.columns.drop(list(pop_df9.filter(regex='age15')))]
pop_df11 = pop_df10[pop_df10.columns.drop(list(pop_df10.filter(regex='age20')))]
pop_df12 = pop_df11[pop_df11.columns.drop(list(pop_df11.filter(regex='age25')))]
pop_df13 = pop_df12[pop_df12.columns.drop(list(pop_df12.filter(regex='age30')))]
pop_df14 = pop_df13[pop_df13.columns.drop(list(pop_df13.filter(regex='age35')))]
pop_df15 = pop_df14[pop_df14.columns.drop(list(pop_df14.filter(regex='age40')))]
pop_df16 = pop_df15[pop_df15.columns.drop(list(pop_df15.filter(regex='age45')))]
pop_df16.shape
# Out:
# (96, 183)

# %%
list(pop_df16)
# Out:
# ['GEO.id',
#  'GEO.id2',
#  'GEO.display-label',
#  'cen42010sex0_age999',
#  'cen42010sex1_age999',
#  'cen42010sex2_age999',
#  'est72010sex0_age999',
#  'est72010sex1_age999',
#  'est72010sex2_age999',
#  'est72014sex0_age999',
#  'est72014sex1_age999',
#  'est72014sex2_age999',
#  'est72017sex0_age999',
#  'est72017sex1_age999',
#  'est72017sex2_age999',
#  'cen42010sex0_age60to64',
#  'cen42010sex1_age60to64',
#  'cen42010sex2_age60to64',
#  'est72010sex0_age60to64',
#  'est72010sex1_age60to64',
#  'est72010sex2_age60to64',
#  'est72014sex0_age60to64',
#  'est72014sex1_age60to64',
#  'est72014sex2_age60to64',
#  'est72017sex0_age60to64',
#  'est72017sex1_age60to64',
#  'est72017sex2_age60to64',
#  'cen42010sex0_age65to69',
#  'cen42010sex1_age65to69',
#  'cen42010sex2_age65to69',
#  'est72010sex0_age65to69',
#  'est72010sex1_age65to69',
#  'est72010sex2_age65to69',
#  'est72014sex0_age65to69',
#  'est72014sex1_age65to69',
#  'est72014sex2_age65to69',
# ...
