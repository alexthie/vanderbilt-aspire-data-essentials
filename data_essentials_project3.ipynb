# %%
import pandas as pd

# %%
### import data

# %%
#import os
#cwd = os.getcwd()
#cwd

# %%
#os.chdir('/Users/thiemia/vanderbilt-aspire-data-essentials')

# %%
hospice_df = pd.read_csv('data/Hospice_General_Information.csv')

# %%
hospice_df.tail(5)
# Out:
#       CMS Certification Number (CCN)                 Facility Name  \
# 4638                          921720  COMFORTING CARE HOSPICE, INC
# 4639                          921721     BLESSED HOPE HOSPICE, INC
# 4640                          921722        VISTA HOSPICE CARE INC
# 4641                          921723          NORCAL HOSPICE, INC.
# 4642                          921729   AFFECTIVE HOSPICE CARE, INC
#
#                          Address Line 1  Address Line 2            City State  \
# 4638  5924 E LOS ANGELES AVENUE SUITE L             NaN     SIMI VALLEY    CA
# 4639       2619 S WATERMAN AVE, SUITE D             NaN  SAN BERNARDINO    CA
# 4640      550 WEST VISTA WAY, SUITE 310             NaN           VISTA    CA
# 4641       700 W. 6TH STREET, SUITE K-B             NaN          GILROY    CA
# 4642  5050 PALO VERDE STREET, SUITE 208             NaN       MONTCLAIR    CA
#
#       Zip Code     County Name     PhoneNumber  CMS Region Ownership Type  \
# ...

# %%
hospice_df = hospice_df.loc[hospice_df.State =='TN']
hospice_df.head(5)
# Out:
#       CMS Certification Number (CCN)                       Facility Name  \
# 2889                          441501                   ALIVE HOSPICE INC
# 2890                          441502          METHODIST ALLIANCE HOSPICE
# 2891                          441504          HOSPICE OF CHATTANOOGA INC
# 2892                          441506               AMEDISYS HOSPICE CARE
# 2893                          441507  NORTHCREST HOME HEALTH AND HOSPICE
#
#                          Address Line 1  Address Line 2         City State  \
# 2889                1718 PATTERSON ROAD             NaN    NASHVILLE    TN
# 2890  6400 SHELBY VIEW DRIVE, SUITE 101             NaN      MEMPHIS    TN
# 2891                 4411 OAKWOOD DRIVE             NaN  CHATTANOOGA    TN
# 2892          6570 STAGE ROAD SUITE 110             NaN     BARTLETT    TN
# 2893               212 NORTHCREST DRIVE             NaN  SPRINGFIELD    TN
#
#       Zip Code County Name     PhoneNumber  CMS Region Ownership Type  \
# ...

# %%
# Keep only the **Facility Name**, **Address Line 1**, **City**, **State**, **County Name**, **CMS Region**, **Ownership Type**, and **Cerfification Date** columns. Make all column names lower case and without spaces.  
hospice_df.columns = ['ccn','facility','address','address2','city',
                      'state','zip','county','phone','region','owner_type','cert_date']
hospice_df.head(2)
# Out:
#          ccn                    facility                            address  \
# 2889  441501           ALIVE HOSPICE INC                1718 PATTERSON ROAD
# 2890  441502  METHODIST ALLIANCE HOSPICE  6400 SHELBY VIEW DRIVE, SUITE 101
#
#       address2       city state    zip    county           phone  region  \
# 2889       NaN  NASHVILLE    TN  37203  Davidson  (615) 327-1085       4
# 2890       NaN    MEMPHIS    TN  38134    Shelby  (901) 516-1600       4
#
#       owner_type   cert_date
# 2889  Non-Profit  04/10/1984
# 2890  Non-Profit  08/31/1984

# %%
hospice_df.count()
# Out:
# ccn           56
# facility      56
# address       56
# address2       0
# city          56
# state         56
# zip           56
# county        56
# phone         56
# region        56
# owner_type    56
# cert_date     56
# dtype: int64

# %%
#Examine the first 5 rows and the last five rows of the TN hospice data.

# %%
hospice_df.drop(columns=['ccn', 'address2','zip','phone'])
# Out:
#                                                facility  \
# 2889                                  ALIVE HOSPICE INC
# 2890                         METHODIST ALLIANCE HOSPICE
# 2891                         HOSPICE OF CHATTANOOGA INC
# 2892                              AMEDISYS HOSPICE CARE
# 2893                 NORTHCREST HOME HEALTH AND HOSPICE
# 2894                   HOSPICE OF CUMBERLAND COUNTY INC
# 2895                                  HIGHPOINT HOSPICE
# 2896                          HOSPICE OF WEST TENNESSEE
# 2897                                    KINDRED HOSPICE
# 2898                        TENNOVA HOSPICE-CLARKSVILLE
# 2899                AMEDISYS HOSPICE AN ADVENTA COMPANY
# 2900                   BLOUNT MEMORIAL HOSPITAL HOSPICE
# 2901                      ASERACARE HOSPICE - NASHVILLE
# 2902                                   SUNCREST HOSPICE
# 2903            LINCOLN MEDICAL HOME HEALTH AND HOSPICE
# 2904               AMEDISYS HOSPICE, AN ADVENTA COMPANY
# ...

# %%
hospice_df.shape
# Out:
# (56, 12)

# %%
cancer_df = pd.read_csv('data/cancer_deaths.csv', skiprows=4, nrows=97)

# %%
cancer_df.head()
# Out:
#              County   FIPS Met Healthy People Objective of 161.4?  \
# 0         Tennessee  47999                                     No
# 1     United States      0                                     No
# 2  Trousdale County  47169                                     No
# 3      Scott County  47151                                     No
# 4   Cheatham County  47021                                     No
#
#    Age-Adjusted Death Rate - deaths per 100,000  \
# 0                                         185.4
# 1                                         163.5
# 2                                         265.5
# 3                                         241.0
# 4                                         239.6
#
#    Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                          184.0                          186.8
# 1                          163.3                          163.7
# 2                          219.0                          319.1
# ...

# %%
#Print the shape of the cancer data.

# %%
cancer_df.shape
# Out:
# (97, 11)

# %%
cancer_df.columns = ['county','fips','objmet','deathrate','lowconfi',
                      'upconfi','avgcount','rectrend','rectrend5ydeathrate','lowconfi1','upconfi1']
cancer_df.head(2)
# Out:
#           county   fips objmet  deathrate  lowconfi  upconfi  avgcount  \
# 0      Tennessee  47999     No      185.4     184.0    186.8     13933
# 1  United States      0     No      163.5     163.3    163.7    586354
#
#   rectrend  rectrend5ydeathrate  lowconfi1  upconfi1
# 0  falling                 -1.4       -1.5      -1.2
# 1  falling                 -1.5       -1.6      -1.5

# %%
pop_df = pd.read_csv('data/PEP_2017_PEPAGESEX.csv',skiprows=1)
#pop_df.iloc[3:]
pop_df.head(2)
# Out:
#                Id    Id2                   Geography  \
# 0  0500000US47001  47001  Anderson County, Tennessee
# 1  0500000US47003  47003   Bedford County, Tennessee
#
#    April 1, 2010 - Census - Both Sexes; Total  \
# 0                                       75129
# 1                                       45058
#
#    April 1, 2010 - Census - Male; Total  \
# 0                                 36308
# 1                                 22357
#
#    April 1, 2010 - Census - Female; Total  \
# 0                                   38821
# 1                                   22701
#
#    April 1, 2010 - Estimates Base - Both Sexes; Total  \
# 0                                              75094
# 1                                              45056
#
#    April 1, 2010 - Estimates Base - Male; Total  \
# 0                                         36288
# 1                                         22356
#
#    April 1, 2010 - Estimates Base - Female; Total  \
# ...

# %%
pop_df.shape
# Out:
# (95, 993)

# %%
#keep only columns that pertain to 2010, 2014, and 2017

# %%
pop_df1 = pop_df[pop_df.columns.drop(list(pop_df.filter(
    regex='Id|Id2|April|2011|2012|2013|2015|2016|to 14|15|16|20 to|25|30|35|45|40|18|Male|Female|5 to 9|Under 5|65 years|Both Sexes; 85 years and over')))]
pop_df1.shape
# Out:
# (95, 31)

# %%
list(pop_df1)
# Out:
# ['Geography',
#  'Population Estimate (as of July 1) - 2010 - Both Sexes; Total',
#  'Population Estimate (as of July 1) - 2014 - Both Sexes; Total',
#  'Population Estimate (as of July 1) - 2017 - Both Sexes; Total',
#  'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 50 to 54 years',
#  'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 50 to 54 years',
#  'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 50 to 54 years',
#  'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 55 to 59 years',
#  'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 55 to 59 years',
#  'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 55 to 59 years',
#  'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 60 to 64 years',
#  'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 60 to 64 years',
#  'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 60 to 64 years',
# ...

# %%
#In the end, you should have these 31 columns:  
 #  `'county', 'pop2010all', 'pop2014all', 'pop2017all', 'median_age_2010', 'median_age_2014', 'median_age_2017', 'pop2010_50to54','pop2014_50to54', 'pop2017_50to54', 'pop2010_55to59', 'pop2014_55to59', 'pop2017_55to59', 'pop2010_60to64', 'pop2014_60to64', 'pop2017_60to64',
  #  'pop2010_65to69', 'pop2014_65to69', 'pop2017_65to69', 'pop2010_70to74', 'pop2014_70to74', 'pop2017_70to74', 'pop2010_75to79', 'pop2014_75to79', 'pop2017_75to79', 'pop2010_80to84', 'pop2014_80to84', 'pop2017_80to84',
   # 'pop2010_85over', 'pop2014_85over', 'pop2017_85over'.

# %%
cancer_df.head(2)
# Out:
#           county   fips objmet  deathrate  lowconfi  upconfi  avgcount  \
# 0      Tennessee  47999     No      185.4     184.0    186.8     13933
# 1  United States      0     No      163.5     163.3    163.7    586354
#
#   rectrend  rectrend5ydeathrate  lowconfi1  upconfi1
# 0  falling                 -1.4       -1.5      -1.2
# 1  falling                 -1.5       -1.6      -1.5

# %%
pop_df1.columns = ['county', 'pop2010all', 'pop2014all', 'pop2017all', 'pop2010_50to54','pop2014_50to54', 'pop2017_50to54', 'pop2010_55to59', 'pop2014_55to59', 'pop2017_55to59', 'pop2010_60to64', 'pop2014_60to64', 'pop2017_60to64',
    'pop2010_65to69', 'pop2014_65to69', 'pop2017_65to69', 'pop2010_70to74', 'pop2014_70to74', 'pop2017_70to74', 'pop2010_75to79', 'pop2014_75to79', 'pop2017_75to79', 'pop2010_80to84', 'pop2014_80to84', 'pop2017_80to84',
    'pop2010_85over', 'pop2014_85over', 'pop2017_85over','median_age_2010', 'median_age_2014', 'median_age_2017']

pop_df1.head(2)
# Out:
#                        county  pop2010all  pop2014all  pop2017all  \
# 0  Anderson County, Tennessee       75112       75131       76257
# 1   Bedford County, Tennessee       45086       46259       48117
#
#    pop2010_50to54  pop2014_50to54  pop2017_50to54  pop2010_55to59  \
# 0            5850            5690            5296            5577
# 1            3043            3207            3239            2646
#
#    pop2014_55to59  pop2017_55to59       ...         pop2017_75to79  \
# 0            5689            5643       ...                   2501
# 1            2938            3143       ...                   1321
#
#    pop2010_80to84  pop2014_80to84  pop2017_80to84  pop2010_85over  \
# 0            1969            1779            1785            2135
# 1             756             729             811             647
#
#    pop2014_85over  pop2017_85over  median_age_2010  median_age_2014  \
# 0            2211            2173             42.6             43.3
# ...

# %%
pop_and_cancer = pd.merge(pop_df1, cancer_df, on='county', how='outer'  )

# %%
pop_and_cancer.head()
# Out:
#                        county  pop2010all  pop2014all  pop2017all  \
# 0  Anderson County, Tennessee     75112.0     75131.0     76257.0
# 1   Bedford County, Tennessee     45086.0     46259.0     48117.0
# 2    Benton County, Tennessee     16511.0     16176.0     15986.0
# 3   Bledsoe County, Tennessee     12882.0     14419.0     14717.0
# 4    Blount County, Tennessee    123213.0    125827.0    129929.0
#
#    pop2010_50to54  pop2014_50to54  pop2017_50to54  pop2010_55to59  \
# 0          5850.0          5690.0          5296.0          5577.0
# 1          3043.0          3207.0          3239.0          2646.0
# 2          1259.0          1204.0          1179.0          1224.0
# 3          1005.0          1216.0          1185.0           903.0
# 4          9152.0          9658.0          9522.0          8657.0
#
#    pop2014_55to59  pop2017_55to59    ...     fips  objmet  deathrate  \
# 0          5689.0          5643.0    ...      NaN     NaN        NaN
# ...

# %%
hospice_df.head(2)
# Out:
#          ccn                    facility                            address  \
# 2889  441501           ALIVE HOSPICE INC                1718 PATTERSON ROAD
# 2890  441502  METHODIST ALLIANCE HOSPICE  6400 SHELBY VIEW DRIVE, SUITE 101
#
#       address2       city state    zip    county           phone  region  \
# 2889       NaN  NASHVILLE    TN  37203  Davidson  (615) 327-1085       4
# 2890       NaN    MEMPHIS    TN  38134    Shelby  (901) 516-1600       4
#
#       owner_type   cert_date
# 2889  Non-Profit  04/10/1984
# 2890  Non-Profit  08/31/1984

# %%
mydictionary= df.column.value_counts().to_dict()

# %%
#Use the pandas series `value_counts()` method to create a dictionary called `hospice_per_county`. The key for this dict will be the county name and the value will be the count of hospice facilities in that county. Populate the dictionary for all TN counties by adding the counties with 0 hospice facilities to `hospice_per_county`.

# %%
#hospice_per_county = hospice_df.county.value_counts('facility').to_dict()

# %%
counts = hospice_df.groupby('county').count()

# %%
hospice_per_county = counts['facility']

# %%
hospice_per_county
# Out:
# county
# Blount        1
# Bradley       2
# Carroll       2
# Carter        1
# Claiborne     1
# Cocke         1
# Coffee        1
# Cumberland    1
# Davidson      8
# Fayette       1
# Fentress      1
# Hamblen       1
# Hamilton      5
# Hancock       1
# Henry         1
# Knox          5
# Lincoln       1
# Madison       2
# McMinn        1
# Montgomery    1
# Obion         1
# Perry         1
# Putnam        1
# Robertson     2
# Rutherford    1
# Shelby        5
# Sullivan      1
# Sumner        1
# Washington    2
# Wayne         1
# Williamson    2
# Name: facility, dtype: int64

# %%
#Use the dictionary you created, `hospice_per_county` to populate a new column in `pop_and_cancer`. Call this column `hospice_count`.
hospice_df.shape
# Out:
# (56, 12)

# %%
pop_and_cancer.shape
# Out:
# (192, 41)

# %%
pop_and_cancer2 = pd.merge(pop_and_cancer, hospice_per_county, on='county', how='inner'  )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-d7e92de99089> in <module>()
# ----> 1 pop_and_cancer2 = pd.merge(pop_and_cancer, hospice_per_county, on='county', how='inner'  )
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...
